# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data_clean.csv", index_col=0)

# %%
df
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4     67     5    1  2010    67       S
# 2     36.0    118.0   8.0     72     5    2  2010    72       C
# 3     12.0    149.0  12.6     74     5    3  2010    74      PS
# 4     18.0    313.0  11.5     62     5    4  2010    62       S
# 5      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 154   41.0    190.0   7.4     67     5    1  2010    67       C
# 155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 156    NaN    145.0  13.2     77     9   27  2010    77       S
# 157   14.0    191.0  14.3     75     9   28  2010    75       S
# 158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    object
#  4   Month    158 non-null    object
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 12.3+ KB

# %%
df.shape
# Out:
# (158, 9)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 1422

# %%
df.describe()
# Out:
#             Ozone     Solar.R        Wind         Day    Year        Temp
# count  120.000000  151.000000  158.000000  158.000000   158.0  158.000000
# mean    41.583333  185.403974    9.957595   16.006329  2010.0   77.727848
# std     32.620709   88.723103    3.511261    8.997166     0.0    9.377877
# min      1.000000    7.000000    1.700000    1.000000  2010.0   56.000000
# 25%     18.000000  119.000000    7.400000    8.000000  2010.0   72.000000
# 50%     30.500000  197.000000    9.700000   16.000000  2010.0   78.500000
# 75%     61.500000  257.000000   11.875000   24.000000  2010.0   84.000000
# max    168.000000  334.000000   20.700000   31.000000  2010.0   97.000000

# %%
df.isnull().sum()
# Out:
# Ozone      38
# Solar.R     7
# Wind        0
# Temp C      0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
df.isnull().any()
# Out:
# Ozone       True
# Solar.R     True
# Wind       False
# Temp C     False
# Month      False
# Day        False
# Year       False
# Temp       False
# Weather     True
# dtype: bool

# %%
df
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4     67     5    1  2010    67       S
# 2     36.0    118.0   8.0     72     5    2  2010    72       C
# 3     12.0    149.0  12.6     74     5    3  2010    74      PS
# 4     18.0    313.0  11.5     62     5    4  2010    62       S
# 5      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 154   41.0    190.0   7.4     67     5    1  2010    67       C
# 155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 156    NaN    145.0  13.2     77     9   27  2010    77       S
# 157   14.0    191.0  14.3     75     9   28  2010    75       S
# 158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    object
#  4   Month    158 non-null    object
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 12.3+ KB

# %%
df.corr()
# Out:
#             Ozone   Solar.R      Wind       Day  Year      Temp
# Ozone    1.000000  0.348642 -0.593530 -0.035055   NaN  0.694098
# Solar.R  0.348642  1.000000 -0.056594 -0.154212   NaN  0.273322
# Wind    -0.593530 -0.056594  1.000000  0.040151   NaN -0.441247
# Day     -0.035055 -0.154212  0.040151  1.000000   NaN -0.124538
# Year          NaN       NaN       NaN       NaN   NaN       NaN
# Temp     0.694098  0.273322 -0.441247 -0.124538   NaN  1.000000

# %%
df =  df.drop(['Temp C'], axis=1)

# %%
df['Month'] = pd.to_numeric(df['Month'], errors='coerce')
df['Weather'] = df['Weather'].astype('category')
df
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4    5.0    1  2010    67       S
# 2     36.0    118.0   8.0    5.0    2  2010    72       C
# 3     12.0    149.0  12.6    5.0    3  2010    74      PS
# 4     18.0    313.0  11.5    5.0    4  2010    62       S
# 5      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 154   41.0    190.0   7.4    5.0    1  2010    67       C
# 155   30.0    193.0   6.9    9.0   26  2010    70      PS
# 156    NaN    145.0  13.2    9.0   27  2010    77       S
# 157   14.0    191.0  14.3    9.0   28  2010    75       S
# 158   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df.dtypes
# Out:
# Ozone       float64
# Solar.R     float64
# Wind        float64
# Month       float64
# Day           int64
# Year          int64
# Temp          int64
# Weather    category
# dtype: object

# %%
df[df.duplicated()].shape
# Out:
# (1, 8)

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()].shape
# Out:
# (0, 8)

# %%
df = df.rename({'Solar.R':'Solar'},axis=1)

# %%
import seaborn as sns
col = df.columns
sns.heatmap(df.isnull());

# %%
col = df.columns
colours = ['#F0F8FF', '#FAEBD7']
sns.heatmap(df[col].isnull(), cmap=sns.color_palette(colours));

# %%
cols = df.columns
sns.heatmap(df[cols].isnull(),cmap=sns.color_palette(['#FFEBCD','#000000']));

# %%
df.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 5      NaN    NaN  14.3    5.0    5  2010    56       S
# 6     28.0    NaN  14.9    5.0    6  2010    66       C
# 10     NaN  194.0   8.6    5.0   10  2010    69       S
# 11     7.0    NaN   6.9    5.0   11  2010    74       C
# 24    32.0   92.0  12.0    NaN   24  2010    61       C
# 25     NaN   66.0  16.6    5.0   25  2010    57      PS
# 26     NaN  266.0  14.9    5.0   26  2010    58       C
# 27     NaN    NaN   8.0    5.0   27  2010    57      PS
# 32     NaN  286.0   8.6    6.0    1  2010    78       S
# 33     NaN  287.0   9.7    6.0    2  2010    74       C
# 34     NaN  242.0  16.1    6.0    3  2010    67      PS
# 35     NaN  186.0   9.2    6.0    4  2010    84       C
# 36     NaN  220.0   8.6    6.0    5  2010    85      PS
# 37     NaN  264.0  14.3    6.0    6  2010    79       C
# 39     NaN  273.0   6.9    6.0    8  2010    87       S
# 42     NaN  259.0  10.9    6.0   11  2010    93       C
# ...

# %%
df['Ozone'] = df['Ozone'].fillna(df['Ozone'].mean())
df['Solar'] = df['Solar'].fillna(df['Solar'].mean())
df['Month'] = df['Month'].fillna(df['Month'].mode().iloc[0])
df['Weather'] = df['Weather'].fillna(df['Weather'].mode().iloc[0])

# %%
df.isna().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar, Wind, Month, Day, Year, Temp, Weather]
# Index: []

# %%
df['Weather'].mode()
# Out:
# 0    S
# Name: Weather, dtype: category
# Categories (3, object): ['C', 'PS', 'S']

# %%
df['Month'].mode()
# Out:
# 0    9.0
# Name: Month, dtype: float64

# %%
df['Year'].value_counts()
# Out:
# 2010    157
# Name: Year, dtype: int64

# %%
df.boxplot();

# %%
df = df.drop(['Year'], axis=1)

# %%
df
# Out:
#          Ozone       Solar  Wind  Month  Day  Temp Weather
# 1    41.000000  190.000000   7.4    5.0    1    67       S
# 2    36.000000  118.000000   8.0    5.0    2    72       C
# 3    12.000000  149.000000  12.6    5.0    3    74      PS
# 4    18.000000  313.000000  11.5    5.0    4    62       S
# 5    41.815126  185.366667  14.3    5.0    5    56       S
# ..         ...         ...   ...    ...  ...   ...     ...
# 153  20.000000  223.000000  11.5    9.0   30    68       S
# 154  41.000000  190.000000   7.4    5.0    1    67       C
# 155  30.000000  193.000000   6.9    9.0   26    70      PS
# 156  41.815126  145.000000  13.2    9.0   27    77       S
# 158  18.000000  131.000000   8.0    9.0   29    76       C
#
# [157 rows x 7 columns]

# %%
df['Weather'].value_counts().plot.bar();

# %%
df['Month'].value_counts().plot.bar();

# %%
df['Month'] = df['Month'].fillna(df['Month'].mean())
